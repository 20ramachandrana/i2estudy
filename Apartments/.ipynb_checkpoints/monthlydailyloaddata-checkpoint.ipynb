# %%
# Setup for the module
import csv
import numpy as np
import matplotlib.pyplot as plt
import time
from datetime import date, datetime
fn = 'Apt106_2015.csv'

# %%
# %matplotlib notebook
# Prints the load for each day of the month for building Apt 100 based on the average every hour,
# data trends eclipsed as a whole for each individual day

# opens the csv file
with open(fn, newline = '') as csvfile:
            reader = csv.reader(csvfile, 'excel')
            ti, usage = zip(*reader)
            t = [None]*(len(ti)//4)
            u = np.zeros(len(usage)//4)
            
            # averaging mechanism for the points for each hour
            for i in range(0, len(usage), 4):
                if(i >= len(u)):
                    break  
                if (i == len(u) - 3):
                    u[i:i+3] = 3*[np.average([float(x) for x in usage[i:i+4]])]
                    break
                u[i:i+4] = 4*[np.average([float(x) for x in usage[i:i+4]])]
            
            # getting the associated axis labels for days of the month                      
            for i in range(0, len(ti), 4):
                if(i >= len(t)):
                    break
                t[i:i+4] = 4*[datetime.fromisoformat(ti[i]).isoformat()]
            ap1 = t.index("2015-04-01T00:00:00")
            u = u[ap1:ap1+24*4*30]
            # plot settings, spacing the days out on the x axis
            t = (1/96) * np.array(range(0, len(u)))
            plt.plot(t, u)
            plt.xticks(np.arange(1,30,7))
            plt.title("Daily Load Data for {} in April 2015".format(fn[:-9]))
            plt.xlabel("Day of Month in April 2015")
            plt.ylabel("Load (kW)")
            plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Prints the load for each day of the month for building Apt 100 based on the average every hour,
# data trends eclipsed as a whole for each individual day
# %matplotlib notebook
# opens the csv file
with open(fn, newline = '') as csvfile:
            reader = csv.reader(csvfile, 'excel')
            ti, usage = zip(*reader)
            t = [None]*(len(ti)//4)
            u = np.zeros(len(usage)//4)
            
            # averaging mechanism for the points for each hour
            for i in range(0, len(usage), 4):
                if(i >= len(u)):
                    break  
                if (i == len(u) - 3):
                    u[i:i+3] = 3*[np.average([float(x) for x in usage[i:i+4]])]
                    break
                u[i:i+4] = 4*[np.average([float(x) for x in usage[i:i+4]])]
            
            # getting the associated axis labels for days of the month                      
            for i in range(0, len(ti), 4):
                if(i >= len(t)):
                    break
                t[i:i+4] = 4*[datetime.fromisoformat(ti[i]).isoformat()]
            a = 0
            while (a < 1 or a > 30):
                a = int(input("What day of April's data do you want to see? "))

            ap1 = t.index("2015-04-01T00:00:00")+(a-1)*24*4
            t = [int(x[11:13]) for x in t[ap1:ap1+24*4]]
            u = u[ap1:ap1+24*4]
            # plot settings, spacing the days out on the x axis
            plt.plot(t,u)
            plt.title("Hourly Load Data for {} on April {} 2015".format(fn[:-9], a))
            plt.xlabel("Time (24hr) on April {}".format(a))
            plt.ylabel("Load (kW)")
            plt.show()
# Out:
# What day of April's data do you want to see? 1
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

# Prints the load for each day of the month for building Apt 100 based on the average every hour,
# data trends eclipsed as a whole for each individual day
for i in range(1, 31):
    # opens the csv file
    if (i < 10):
        f = "solar_2015-04-0{}.csv".format(i)
    else:
        f = "solar_2015-04-0{}.csv".format(i)
    with open(f, newline = '') as csvfile:
                reader = csv.reader(csvfile, 'excel')
                ti,lo,gen = zip(*reader)
                t = [None]*(len(ti)//60)
                u = np.zeros(len(gen)//60)

                # averaging mechanism for the points for each hour
                for i in range(0, len(gen), 60):
                    if(i >= len(u)):
                        break  
                    if (i == len(u) - 59):
                        u[i:i+59] = 59*[np.average([float(x) for x in gen[i:i+60]])]
                        break
                    u[i:i+60] = 60*[np.average([float(x) for x in gen[i:i+60]])]

                # getting the associated axis labels for days of the month                      
                for i in range(0, len(ti), 60):
                    if(i >= len(t)):
                        break
                    t[i:i+60] = 60*[datetime.fromisoformat(ti[i]).isoformat()]
                if (i < 10):
                    ap1 = t.index("2015-04-0{i}T00:00:00").format(i)
                else:
                    ap1 = t.index("2015-04-{i}T00:00:00").format(i)   
                # plot settings, spacing the days out on the x axis
                t = (1/(60*24)) * np.array(range(0, len(u)))
                plt.plot(t, u)
                plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-d72aa7078a5d> in <module>
#       9     else:
#      10         f = "/106/solar_2015-04-0{}.csv".format(i)
# ---> 11     with open(f, newline = '') as csvfile:
#      12                 reader = csv.reader(csvfile, 'excel')
#      13                 ti,lo,gen = zip(*reader)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/106/solar_2015-04-01.csv'
